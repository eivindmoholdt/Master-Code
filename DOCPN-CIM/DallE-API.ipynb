# %% [markdown]
# # Image Generation using DallE API

# %% [markdown]
# OpenAIs API allows us to access DallE and generate images from the console.
# The API request returns a JSON file including an URL to the image, pointing to DallE website where the image is stored.
# We can tell the request to return a Base64 JSON response which we can decode into a PNG file, which allows us to save the image to a local directory.
#
# This process is more complex than using SD model via huggingface, as we first need to save a JSON file and access it before finally converting the image to a PNG or JPG file which we can use.
#
#
# Stable Diffusion model uses about **3** seconds to generate each image and save it to our folder with **premium colab GPU**
#
# Stable Diffusion model uses about **15** seconds to generate each image and save it to our folder with **standard colab GPU**
#
#
# Dall-E returns the JSON response and decodes the response and saves to PNG file in **6-7** seconds with **standard colab GPU**

# %% [markdown]
# # Install and set API key

# %%
# cd into COSMOS2 folder before running code below. 
# The dataset is stored in /content/drive/MyDrive/COSMOS2/SDv14-GeneratedDataset
# %cd drive/MyDrive/COSMOS2
# Out:
# /content/drive/MyDrive/COSMOS2

# %%
# !python -m pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 2.8 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 15.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.5 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.2 yarl-1.8.2

# %%
# !which openai
# Out:
# /usr/local/bin/openai

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (67.6.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (2.14.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.18.2
# time: 362 µs (started: 2023-03-29 08:25:53 +00:00)

# %%
# !pip install OpenCV-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: OpenCV-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/dist-packages (from OpenCV-python) (1.22.4)
# time: 3.22 s (started: 2023-03-29 08:25:53 +00:00)

# %%
# !pip install matplotlib
# !pip install pandas
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# time: 9.65 s (started: 2023-03-29 08:25:56 +00:00)

# %% [markdown]
# Set API key.
# Sign up for the OpenAI API and create a new API key by clicking on the dropdown menu on your profile and selecting View API keys

# %% [markdown]
# # Generate Images using API

# %%
OPENAI_API_KEY="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"
# Out:
# time: 547 µs (started: 2023-03-29 08:26:06 +00:00)

# %% [markdown]
# Create Image from Prompt.
# this code sends an authenticated request to the API that generates a single image based on the text in PROMPT.
#
# Script returns a JSON file with the URL for the image.
# The URL is only available online for 24 hours.

# %% [markdown]
# The API allows you to switch the response format from a URL to the Base64-encoded image data. In line 15, you set the value of response_format to "b64_json".
#
# We can later Decode the Base64 string to view the image and save as a PNG

# %% [markdown]
# Stable Diffusion returns images in 512x512 pixel size.
# Dall-E lets us choose between sizes, at different cost.
# We choose 512x512 here as well to ensure comparability between the models when comparing the images at later stage.
#
# Resolution	- Price per image
# * 256×256	- $0.016
#
# * 512×512	- $0.018
#
#
# * 1024×1024	- $0.020

# %% [markdown]
# **Test image generation**

# %%
import cv2
from google.colab.patches import cv2_imshow
import json
import os
from pathlib import Path

import openai

PROMPT = "Student drinking coffee and writing a master thesis"
DATA_DIR = Path.cwd() / "responses"

DATA_DIR.mkdir(exist_ok=True)

openai.api_key = OPENAI_API_KEY

#request image from Dall-E
response = openai.Image.create(
    prompt=PROMPT,
    n=1,
    size="512x512",
    response_format="b64_json",
)

#save JSON response file
file_name = DATA_DIR / f"{PROMPT[:5]}-{response['created']}.json"

with open(file_name, mode="w", encoding="utf-8") as file:
    json.dump(response, file)

#The script then fetches the Base64-encoded string from the JSON data,
#decodes it, and saves the resulting image data as a PNG file in a directory. 

import json
from base64 import b64decode
from pathlib import Path



DATA_DIR = Path.cwd() / "responses"
JSON_FILE =file_name
IMAGE_DIR = Path.cwd() / "images" / JSON_FILE.stem

IMAGE_DIR.mkdir(parents=True, exist_ok=True)

with open(JSON_FILE, mode="r", encoding="utf-8") as file:
    response = json.load(file)

for index, image_dict in enumerate(response["data"]):
    image_data = b64decode(image_dict["b64_json"])
    image_file = IMAGE_DIR / f"{JSON_FILE.stem}-{index}.png"
    print(image_file)
    with open(image_file, mode="wb") as png:
        png.write(image_data)

    #show the saved image in Colab 
    im = cv2.imread(str(image_file))
    cv2_imshow(im)
# Out:
# /content/drive/MyDrive/DallE-API/images/Stude-1678797746/Stude-1678797746-0.png
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAE84F07FD0>
# time: 6.88 s (started: 2023-03-14 12:42:21 +00:00)

# %% [markdown]
# # Generate images for COSMOS test dataset

# %%
# !pip install torch torchvision torchaudio
# !pip install diffusers
# !pip install transformers scipy ftfy
# !pip install ipywidgets==7.7.2
# !pip install accelerate
#!python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (0.14.1+cu116)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.9/dist-packages (0.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffusers
#   Downloading diffusers-0.14.0-py3-none-any.whl (737 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 KB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers) (1.22.4)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from diffusers) (6.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers) (2.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers) (3.10.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (4.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (2022.12.7)
# Installing collected packages: huggingface-hub, diffusers
# Successfully installed diffusers-0.14.0 huggingface-hub-0.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (1.10.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy) (0.2.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, ftfy, transformers
# Successfully installed ftfy-6.1.1 tokenizers-0.13.2 transformers-4.27.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipywidgets==7.7.2
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 KB 381.5 kB/s eta 0:00:00
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets==7.7.2) (3.6.3)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.4-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets==7.7.2) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets==7.7.2) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets==7.7.2) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets==7.7.2) (7.9.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2) (6.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (2.14.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.2) (67.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets==7.7.2) (0.8.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (6.5.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (5.8.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (23.2.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.2) (2.8.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.7.2) (1.16.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.7.2) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets==7.7.2) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (3.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (2.1.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (4.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (6.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (23.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.7.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (1.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.7.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (2.16.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2) (2.21)
# Installing collected packages: jupyterlab-widgets, ipywidgets
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.6
#     Uninstalling jupyterlab-widgets-3.0.6:
#       Successfully uninstalled jupyterlab-widgets-3.0.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed ipywidgets-7.7.2 jupyterlab-widgets-1.1.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from accelerate) (1.13.1+cu116)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate) (5.9.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate) (23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate) (4.5.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.18.0
# time: 33.2 s (started: 2023-03-29 08:26:06 +00:00)

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
#Check that torch, cuda and detectron2 is OK
import torch
import detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# torch:  1.13 ; cuda:  cu116
# detectron2: 0.6
# time: 1.45 s (started: 2023-03-29 08:30:09 +00:00)

# %%
from google.colab.patches import cv2_imshow
from pathlib import Path
import openai
from base64 import b64decode
from pathlib import Path
from torch import autocast
from diffusers import StableDiffusionPipeline
from PIL import Image
import spacy
import os
import pandas as pd
import torch
from torchtext import data
import json
import cv2
from utils.config import DATA_DIR, embed_type
from utils.common_utils import read_json_data
from utils.text_utils import get_caption_list, retrieve_captions
from nltk.stem.snowball import SnowballStemmer
# python3 -m spacy download en
spacy_en = spacy.load('en_core_web_sm')
stemmer = SnowballStemmer(language="english")
from torchtext.vocab import GloVe, FastText

# Generate specific images
#test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json')) [0:5]
#Generate all images
test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json'))[957:]

count = 957
for i in test_data:
  description_1 = i['caption1_modified']
  description_2 = i['caption2_modified']

  # do censoring
  with open('badwords.txt','r') as f:
    for line in f:
      for word in line.split(","):
        description_1 = description_1.replace(word, ''*len(word))
        description_2 = description_2.replace(word, ''*len(word))

  DATA_DIR = Path.cwd() / "DallE-GeneratedDataset/responses"
  DATA_DIR.mkdir(exist_ok=True)
  openai.api_key = OPENAI_API_KEY

  print(description_1)
  print(description_2)

  #request image from Dall-E
  response1 = openai.Image.create(
      prompt=description_1,
      n=1,
      size="512x512",
      response_format="b64_json",
  )

  #request image from Dall-E
  response2 = openai.Image.create(
      prompt=description_2,
      n=1,
      size="512x512",
      response_format="b64_json",
  )

  #save JSON response files
  file_name1 = DATA_DIR / f"{count}_gen1.json"
  file_name2 = DATA_DIR / f"{count}_gen2.json"


  with open(file_name1, mode="w", encoding="utf-8") as file:
      json.dump(response1, file)
  with open(file_name2, mode="w", encoding="utf-8") as file:
      json.dump(response2, file)

  IMAGE_DIR = Path.cwd() / "DallE-GeneratedDataset/images"

  IMAGE_DIR.mkdir(parents=True, exist_ok=True)

  #The script then fetches the Base64-encoded string from the JSON data,
  #decodes it, and saves the resulting image data as a PNG file in a directory. 

  with open(file_name1, mode="r", encoding="utf-8") as file1:
      response1 = json.load(file1)

  for index1, image_dict1 in enumerate(response1["data"]):
      image_data1 = b64decode(image_dict1["b64_json"])
      image_file1 = IMAGE_DIR / f"{count}_gen1.png"
      print(image_file1)
      with open(image_file1, mode="wb") as png1:
          png1.write(image_data1)

  with open(file_name2, mode="r", encoding="utf-8") as file2:
      response2 = json.load(file2)

  for index2, image_dict2 in enumerate(response2["data"]):
      image_data2 = b64decode(image_dict2["b64_json"])
      image_file2 = IMAGE_DIR / f"{count}_gen2.png"
      print(image_file2)
      with open(image_file2, mode="wb") as png2:
          png2.write(image_data2)
  

  count = count + 1
# Out:
# PERSON, on the set of her ORG show, which was canceled in DATE.
# PERSON on the set of her new daytime show, “WORK_OF_ART,” at FAC in GPE, DATE. After her "" remarks — and middling ratings — PERSON will not return to her TIME program on ORG, the network said on DATE.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1275_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1275_gen2.png
# A NORP family enjoy themselves at a safe distance from other cinemagoers at a drive-in film festival in GPE on DATE.
# A family watch a movie screening at ORG.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1276_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1276_gen2.png
# Mari and PERSON at home, in GPE, PERSON
# A tattooed woman and her adult son pose in their home
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1277_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1277_gen2.png
# A riot police officer in GPE had her helmet visor painted red by a member of a feminist collective, during a protest against gender-based violence in the country.
# A riot police officer with her helmet visor painted red
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1278_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1278_gen2.png
# Backless booster seats would be illegal in GPE starting in DATE.
# Parents who continue to put their children in booster cushions can continue to do so without breaking any laws in the GPE.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1279_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1279_gen2.png
# Presidential daughter PERSON was named the highest-paid heir in DATE.
# False rumors that ORDINAL Daughter PERSON was named the Highest-Paid Heir were started by a satire publication.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1280_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1280_gen2.png
# Secretary of ORG PERSON delivering a speech at the American University GPE.
# GPE Secretary of ORG PERSON speaks at ORG in GPE.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1281_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1281_gen2.png
# The photograph of President PERSON's inauguration that was displayed during Mr. PERSON's briefing. Mr. PERSON said that when he looked out from his podium, "it looked like CARDINAL, CARDINAL people.
# ORG's inauguration.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1282_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1282_gen2.png
# Here children raise their hand as his open-top vehicle cruises past
# Children raise their arms as PERSON travels past in GPE, GPE
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1283_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1283_gen2.png
# On DATE, GPE President PERSON said LAW is a “phony argument.”
#  did not say that LAW is a “phony argument.”
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1284_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1284_gen2.png
# In DATE, a video supposedly showing a member of the PERSON tribe  people in the streets who were not obeying the NORP government’s shelter-in-place order was circulated on social media.
# This video actually comes from a NORP comedian and was created for entertainment purposes.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1285_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1285_gen2.png
# A photograph shows PERSON at a family birthday party with PERSON in DATE.
# This photograph was not taken at a party for “WORK_OF_ART’s kid.” It was actually taken in DATE at a birthday party for ORG’s son, PERSON, who had just turned CARDINAL.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1286_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1286_gen2.png
# Cruise Ship Company Carnival Fined $ORG Oceans
# The image captures a cruise ship dropping anchor off the coast of ORG, GPE.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1287_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1287_gen2.png
# A photograph shows GPE President PERSON touching the face of a wounded veteran who lost both of his arms because the president knew the man couldn't shake hands.
# This photograph was taken in DATE during a ORG rally in GPE, GPE, and shows a man named PERSON” PERSON Jr. While  did touch PERSON’s face, Stevenson is not a wounded veteran.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1288_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1288_gen2.png
# NORP chain PERSON is removing pork from its menu to appease offended NORP customers.
# An unverified claim that PERSON was removing pork from its menu to appease NORP was later labeled as "satire."
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1289_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1289_gen2.png
# A state of emergency was been declared in the GPE city of GPE over concerns that large crowds gathering for spring break pose a  risk.
# People leave the GPE area as an QUANTITY goes into effect on DATE in GPE.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1290_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1290_gen2.png
# A video shows a "UFO" flying over GPE in DATE.
# this may have been an unidentified flying object to these onlookers, this “alien spaceship” has since been identified as ORG.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1291_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1291_gen2.png
# GPE officials pour alcohol down a sewer
# A barrel of confiscated illegal beer being poured down a drain.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1292_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1292_gen2.png
# The children's character Elmo asked if it was OK to use a  if "Elmo is just singing along to Elmo’s favorite song."
# This is not a genuine Elmo quote from “WORK_OF_ART.”
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1293_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1293_gen2.png
# The picture dated from EVENT and captured a soldier carrying the animal in order to keep it from inadvertently tripping landmines and ing everyone around it
# The picture actually dates from DATE, during EVENT (i.e., a war for independence waged against NORP forces in LOC). And it depicts a starving donkey that was rescued by a member of ORG who carried it back to his base
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1294_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1294_gen2.png
# GPE lobsterman catches extremely rare purple lobster
# CARDINAL-in-a-million' purple lobster fools the internet
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1295_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1295_gen2.png
# Empty GPE church in GPE, GPE
# PERSON holds Mass
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1296_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1296_gen2.png
# PERSON, an opposition candidate who many people said was denied victory, called on the NORP to "rise as CARDINAL man to protect victory."
# Opposition Candidate PERSON rise as CARDINAL man to protect victory
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1297_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1297_gen2.png
# A worker wields an axe during a public demonstration in front of GPE's FAC cathedral to demonstrate the medieval techniques used to lift part of the reconstructed framework of the cathedral.
# A man uses an axe to chop a tree trunk in front the cathedral of ORG in GPE
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1298_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1298_gen2.png
# President PERSON respectfully touches the face of a GPE veteran who lost both arms, knowing he could no longer enjoy the feel of a handshake.
# This photograph was taken in DATE during a ORG rally in GPE, GPE, and shows a man named PERSON” PERSON Jr. While  did touch PERSON’s face, Stevenson is not a wounded veteran.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1299_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1299_gen2.png
# A GPE newspaper termned the NORP people a 'confederacy of fools' for electing PERSON.
# PERSON, the editor-in-chief of ORG, confirmed that the newspaper “has never published such an article … about PERSON nor about Barack WORK_OF_ART” and that it “primarily reports on events in GPE and LOC and not on domestic affairs in other counties”
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1300_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1300_gen2.png
# And NORP swimmer PERSON Shaaban trains in a pool in GPE on DATE wearing a monofin. DATE he broke the world record for the highest jump from water with a mermaid-like flipper.
# PERSON Shaaban wearing a monofin training in a pool in GPE, GPE - Sunday DATE
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1301_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1301_gen2.png
# A young girl disconnected her grandfather's life support in order to charge her mobile phone.
# A young girl disconnected her grandfather's life support in order to charge her mobile phone is purely a work of fiction.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1302_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1302_gen2.png
# A photograph shows an anti- protester duct-taped to an electrical box by neo-.
# A photograph showing a person duct-taped to an electrical box is a participatory street art series created by artist PERSON
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1303_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1303_gen2.png
# GPE President PERSON touching the face of a wounded veteran who had lost both of his arms
# This photograph was taken in DATE during a ORG rally in GPE, GPE, and shows a man named PERSON” PERSON Jr. While  did touch PERSON’s face, Stevenson is not a wounded veteran.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1304_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1304_gen2.png
# A young woman sits down by CARDINAL of the flowerpots that decorate ORG in GPE
# The photo "WORK_OF_ART" by NORP photographer PERSON, highly appreciated at FAC
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1305_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1305_gen2.png
# Protesters gathered in front of a ORG installation in GPE, GPE, on DATE after security forces surrounded it.
# Security forces fired tear gas against protesters in a poor neighbourhood QUANTITY from GPE’s presidential palace in TIME of today
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1306_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1306_gen2.png
# A photograph show a group of wounded female veterans who have each lost one or both legs.
# Photograph shows a group of NORP women who gathered together for a calendar photo shoot in order to raise money for amputees who cannot afford prosthetic limbs
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1307_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1307_gen2.png
# The legal drinking age has been raised to CARDINAL.
# Flaming cocktail techniques may be learned
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1308_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1308_gen2.png
# A photograph taken by ORG shows bushfires raging across GPE.
# This is a 3D rendering of fire hotspots over DATE from DATE until DATE. It is not a real photo.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1309_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1309_gen2.png
# Did a Pink Volcano Erupt in GPE
# CARDINAL photoshop rendering of pink smoke from volcano
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1310_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1310_gen2.png
# PERSON, DATE, an GPE luthier works in his workshop in GPE, an area of GPE, GPE, CARDINAL September 2020, DATE before EVENT
# On DATE, luthier PERSON works on a guitar at his shop in GPE main city GPE...
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1311_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1311_gen2.png
# PERSON a Lab That ‘Developed’
# When pulled, the thread of ORG, to ORG (NORP), to PERSON, to a biotech research facility in GPE, leads to nothing.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1312_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1312_gen2.png
# NORP Photography and Video Art from the Walther Collection Recent Histories
# Person wearing black dress and red shoes
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1313_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1313_gen2.png
# ORG fighter PERSON has been found dead in her bathtub.
# A fake news site appropriated the name of a popular newspaper to claim ORG fighter PERSON was found dead in her bathtub.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1314_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1314_gen2.png
# Malia  Highest-Paid Heir in the ORG.
# False rumors that ORDINAL Daughter PERSON was named the Highest-Paid Heir were started by a satire publication.
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1315_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1315_gen2.png
# ORG, GPE, GPE, DATE
# A child holds a camera next to a destroyed bus
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1316_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1316_gen2.png
# Members of ORG Wal Amal (Light and Hope) chamber orchestra of blind women wearing protective masks play during their ORDINAL concert, in GPE, GPE, DATE.
# NORP orchestra for visually-impaired women resumes concerts amid
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1317_gen1.png
# /content/drive/MyDrive/COSMOS2/DallE-GeneratedDataset/images/1317_gen2.png
# Louisiana GOP Backs Child Marriage Bill: "WORK_OF_ART of 16-Year-Olds Are Very Mature"
# GPE’s marriage law only required minors (i.e., youths under DATE) to obtain a court order and permission from one parent in order to marry, without specifying any minimum age for marriage.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:50                                                                                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/openai/api_resources/image.py:36 in create                │
# │                                                                                                  │
# │    33 │   │                                                                                      │
# │    34 │   │   _, api_version = cls._get_api_type_and_version(api_type, api_version)              │
# │    35 │   │                                                                                      │
# │ ❱  36 │   │   response, _, api_key = requestor.request(                                          │
# │    37 │   │   │   "post", cls._get_url("generations"), params                                    │
# │    38 │   │   )                                                                                  │
# │    39                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/openai/api_requestor.py:226 in request                    │
# │                                                                                                  │
# │   223 │   │   │   request_id=request_id,                                                         │
# │   224 │   │   │   request_timeout=request_timeout,                                               │
# │   225 │   │   )                                                                                  │
# │ ❱ 226 │   │   resp, got_stream = self._interpret_response(result, stream)                        │
# │   227 │   │   return resp, got_stream, self.api_key                                              │
# │   228 │                                                                                          │
# │   229 │   @overload                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/openai/api_requestor.py:619 in _interpret_response        │
# │                                                                                                  │
# │   616 │   │   │   ), True                                                                        │
# │   617 │   │   else:                                                                              │
# │   618 │   │   │   return (                                                                       │
# │ ❱ 619 │   │   │   │   self._interpret_response_line(                                             │
# │   620 │   │   │   │   │   result.content.decode("utf-8"),                                        │
# │   621 │   │   │   │   │   result.status_code,                                                    │
# │   622 │   │   │   │   │   result.headers,                                                        │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/openai/api_requestor.py:682 in _interpret_response_line   │
# │                                                                                                  │
# │   679 │   │   # to better handle the "error while streaming" case.                               │
# │   680 │   │   stream_error = stream and "error" in resp.data                                     │
# │   681 │   │   if stream_error or not 200 <= rcode < 300:                                         │
# │ ❱ 682 │   │   │   raise self.handle_error_response(                                              │
# │   683 │   │   │   │   rbody, rcode, resp.data, rheaders, stream_error=stream_error               │
# │   684 │   │   │   )                                                                              │
# │   685 │   │   return resp                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# InvalidRequestError: Your request was rejected as a result of our safety system. Your prompt may contain text that
# is not allowed by our safety system.
# time: 8min 53s (started: 2023-03-29 14:06:16 +00:00)

# %%
import locale
print(locale.getpreferredencoding())
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
ls
# Out:
#  bad-words-detector/
#  badwords.txt
#  balloon/
#  balloon_dataset.zip
#  balloon_dataset.zip.1
#  cocoapi/
#  DallE-GeneratedDataset/
#  dataset/
#  dataset_visualizer/
#  detectron2_changes/
#  docs/
#  evaluate_ooc.py
#  gen1.png
#  gen2.png
#  images/
#  input.jpg
#  LICENSE.md
#  __MACOSX/
#  model_archs/
# 'new cosmos'
# '<PIL.Image.Image image mode=RGB size=512x512 at 0x7F4AD78A4A30>.png'
#  Readme.md
#  requirements.txt
#  SDv14-GeneratedDataset/
#  trainer_scipt.py
#  utils/
# time: 110 ms (started: 2023-03-27 08:28:55 +00:00)

# %%
from google.colab.patches import cv2_imshow
from pathlib import Path
import openai
from base64 import b64decode
from pathlib import Path
from torch import autocast
from diffusers import StableDiffusionPipeline
from PIL import Image
import spacy
import os
import pandas as pd
import torch
from torchtext import data
import json
import cv2
from utils.config import DATA_DIR, embed_type
from utils.common_utils import read_json_data
from utils.text_utils import get_caption_list, retrieve_captions
from nltk.stem.snowball import SnowballStemmer
# python3 -m spacy download en
spacy_en = spacy.load('en_core_web_sm')
stemmer = SnowballStemmer(language="english")
from torchtext.vocab import GloVe, FastText

# Generate specific images
test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json')) [:100]
#Generate all images
#test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json'))

# do censoring
for i in test_data:
  text = i['caption1_modified']
  with open('badwords.txt','r') as f:
    for line in f:
      for word in line.split(","):
        text = text.replace(word, ''*len(word))
        word = word.upper()
    print(text)

# %% [markdown]
# wordcloud

# %%
from google.colab.patches import cv2_imshow
from pathlib import Path
import openai
from base64 import b64decode
from pathlib import Path
from torch import autocast
from diffusers import StableDiffusionPipeline
from PIL import Image
import spacy
import os
import pandas as pd
import torch
from torchtext import data
import json
import cv2
from utils.config import DATA_DIR, embed_type
from utils.common_utils import read_json_data
from utils.text_utils import get_caption_list, retrieve_captions
from nltk.stem.snowball import SnowballStemmer
# python3 -m spacy download en
spacy_en = spacy.load('en_core_web_sm')
stemmer = SnowballStemmer(language="english")
from torchtext.vocab import GloVe, FastText

# Generate specific images
test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json')) [:100]
#Generate all images
#test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json'))
# Out:
# /usr/local/lib/python3.9/dist-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(
# time: 1min 7s (started: 2023-03-27 08:36:58 +00:00)

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from utils.config import DATA_DIR, embed_type
test_data = read_json_data(os.path.join(DATA_DIR, 'test_data.json'))

comment_words = ''
stopwords = set(STOPWORDS)

# iterate through the file
for val in test_data:
  text = val['caption2']
  text2 = val['caption1']
  text = str(text+text2)
  tokens = text.split()

  for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()
    
  comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image					
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
# Out:
# time: 1.86 s (started: 2023-03-29 11:25:15 +00:00)

# %% [markdown]
# {"img_local_path": "test/22.jpg", "caption1": "cockapoo, Bailey, during his morning walk in London's Regent's Park", "caption2": "Bailey the cockapoo in London's Regent's Park", "context_label": 0, "article_url": "https://www.bbc.com/news/uk-england-55296373",
#
# "caption1_modified": "PERSON, PERSON, during his TIME walk in GPE's FAC", "caption1_entities": [["cockapoo", "PERSON"], ["Bailey", "PERSON"], ["morning", "TIME"], ["London", "GPE"], ["Regent's Park", "FAC"]],
#
# "caption2_modified": "Bailey the cockapoo in GPE's FAC", "caption2_entities": [["London", "GPE"], ["Regent's Park", "FAC"]], "bert_base_score": "0.78335977", "bert_large_score": "0.7213417"}

# %%
import cv2
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

# Load the pre-trained CNN model
model = VGG16(weights='imagenet', include_top=False)

# Define a function to extract features from an image using the CNN model
def extract_features(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (224, 224))
    img = preprocess_input(img)
    features = model.predict(np.array([img]))
    return features.flatten()

# Load the input images
img1_path = 'DallE-GeneratedDataset/images/153_gen1.png'
img2_path = 'DallE-GeneratedDataset/images/153_gen2.png'

# Extract features from the input images
features1 = extract_features(img1_path)
features2 = extract_features(img2_path)

# Calculate cosine similarity between the feature vectors
similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

print("Cosine similarity between the two images:", similarity)

# Calculate mean squared error between the feature vectors
mse = np.mean(np.square(features1 - features2))

print("MSE between the two images:", mse)
# Out:
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 32ms/step
# Cosine similarity between the two images: 0.09870922
# MSE between the two images: 170.4929
# time: 986 ms (started: 2023-03-27 13:54:40 +00:00)

# %%
import numpy as np
import tensorflow as tf
import cv2

# Load pre-trained CNN model for feature extraction
model = tf.keras.applications.InceptionV3(include_top=False, pooling='avg')

# Define function to extract features from image using the pre-trained model
def extract_features(image_path, model):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    img = np.expand_dims(img, axis=0)
    features = model.predict(img)
    features = features.flatten()
    return features

# Load two images to compare
img1_path = 'DallE-GeneratedDataset/images/141_gen2.png'
img2_path = 'DallE-GeneratedDataset/images/154_gen2.png'


# Extract features from each image
features1 = extract_features(img1_path, model)
features2 = extract_features(img2_path, model)

# Calculate mean squared error between the feature vectors
mse = np.mean(np.square(features1 - features2))

print("MSE between the two images:", mse)

# Calculate cosine similarity between the feature vectors
similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

print("Cosine similarity between the two images:", similarity)

# Calculate the Eucledian distance between the feature vectors of the two images
distance = np.linalg.norm(features1 - features2)

# Print the similarity score
print('Eucledian Distanec Similarity score:', 1 / (1 + distance))
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# MSE between the two images: 0.17342447
# Cosine similarity between the two images: 0.5079599
# Eucledian Distanec Similarity score: 0.05038788410348407

# %%
def remove_bad_words(text, bad_word_1, bad_word_2):
    # Split the text into a list of words
    words = text.split()

    # Iterate through the list of words
    i = 0
    while i < len(words) - 1:
        # Check if the current word and the next word are both bad words
        if words[i].lower() == bad_word_1.lower() and words[i+1].lower() == bad_word_2.lower():
            # Remove the bad words from the list of words
            words.pop(i)
            words.pop(i)  # Note: We need to remove two words because we just removed one, so the next word is now at the same index
        else:
            i += 1

    # Join the list of words back into a single string
    cleaned_text = ' '.join(words)

    return cleaned_text

text = "This is a sentence with just biden. This is a sentence with biden cocain"
with open("badwords.txt", "r") as f:
  for line in f:
    for word1, word2 in line.split():
      if word1 and word2 in text:
        cleaned_text = remove_bad_words(word1, word2)
        print(cleaned_text)
      else:
        pass
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:24                                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: too many values to unpack (expected 2)
# time: 36.2 ms (started: 2023-03-29 09:38:59 +00:00)

# %%
# Open the text file for reading
with open("badwords.txt", "r") as file:

    # Initialize empty lists for single words and concatenated words
    single_words = []
    concatenated_words = []

    # Loop through each line in the file
    for line in file:

        # Split the line into individual words
        words = line.strip().split(",")

        # Loop through each word in the line
        for word in words:

          print(word)
# Out:
# bitch
# cunt
# dago
# daygo
# dego
# dick
# douchebag
# dumb
# dyke
# eskimo
# faggot
# homo
# hooker
# idiot
# kike
# lesbo
# lunatic
# negress
# negro
# nigga
# nigger
# prostitute
# pussy
# retard
# shemale
# tits
# trannie
# tranny
# twat
# whore
# killed
# naked
# sex
# kills
# kill
# cumming
# Cumming
# carving
# consuming
# flipping
# Flipping
# dildo
# Dildo
# DILDO
# turd
# Turd
# turd
# genocide
# Genocide
# reproduction
# Reproduction
# kkk
# KKK
# sperm
# Sperm
# human flesh
# human meat
# pedophile
# Pedohile
# nude
# trafficking
# porn
# pornographic
# death
# murder
# rape
# impregnate
# pregnant
# Pregnant
# asshole
# fuck
# suicide
# coronavirus
# covid-19
# covid
# menstruating
# harassment
# HARASSMENT
# Harassment
# torture
# Torture
# TORTUTE
# whipping
# Whipping
# WHIPPING
# slave
# Slave
# SLAVE
# abortion
# Abortion
# ABORTION
# heroin
# Heroin
# HEROIN
# cocain
# Cocain
# COCAIN
# snow
# Snow
# ecstasy
# Ecstasy
# ECSTASY
# marijuana
# Marijuana
# MARIJUANA
# weed
# Weed
# WEED
# hash
# Hash
# HASH
# isis
# Isis
# ISIS
# nword
# Nword
# N-word
# N-WORD
# Biden
# biden
# BIDEN
# Obama
# obama
# OBAMA
# Trump
# trump
# TRUMP
# Clinton
# clinton
# CLINTON
# putin
# Putin
# PUTIN
# Sanders
# sanders
# SANDERS
# racial
# slur
# Racial
# Slur
# RACIAL
# SLUR
# bdsm
# BDSM
# Bdsm
# antifa
# ANTIFA
# Antifa
# transgender
# Transgender
# TRANSGENDER
# gay
# Gay
# GAY
#
# Homo
# homo
# HOMO
# Bitch
# Cunt
# Dago
# Daygo
# Dego
# Dick
# Douchebag
# Dumb
# Dyke
# Eskimo
# Faggot
# Homo
# Hooker
# Idiot
# Kike
# Lesbo
# Lunatic
# Negress
# Negro
# Nigga
# Nigger
# Prostitute
# Pussy
# Retard
# Shemale
# Tits
# Trannie
# Tranny
# Twat
# Whore
# Killed
# Naked
# Sex
# Kills
# Kill
# Nude
# Trafficking
# Porn
# Pornographic
# Death
# Murder
# Rape
# Impregnate
# Asshole
# Fuck
# Suicide
# Coronavirus
# Covid-19
# Covid
# Menstruating
# time: 38.2 ms (started: 2023-03-29 10:13:52 +00:00)

# %%
import json
with open("dataset/data/test_data.json") as f:
  my_dict = [json.loads(line) for line in f]
  
  for i in my_dict:
    description_1 = i['caption1_modified']
    description_2 = i['caption2_modified']
    with open('badwords.txt','r') as f:
      for line in f:
        for word in line.split(","):
          description_1 = description_1.replace(word, ''*len(word))
          description_2 = description_2.replace(word, ''*len(word))

    data = {
          "img_local_path": i['img_local_path'],
          "original_caption1":i['caption1'],
          "caption1_mod": description_1,
          "img_gen1": f"DallE-GeneratedDataset/images/{i['img_local_path'].translate( { ord(n): None for n in '.jpng/test'} )}_gen1.png",
          "original_caption2":i['caption2'],
          "caption2_mod": description_2,
          "img_gen2": f"DallE-GeneratedDataset/images/{i['img_local_path'].translate( { ord(n): None for n in '.jpng/test'} )}_gen2.png",
          "label": i['context_label']}

    # serialize the data to JSON format
    json_data = json.dumps(data)

    print(json_data)
# Out:
# {"img_local_path": "test/0.jpg", "original_caption1": "Julian Castro at his announcement in San Antonio, Tex., on Saturday. Mr. Castro, the former secretary of housing and urban development, would be one of the youngest presidents if elected.", "caption1_mod": "PERSON at his announcement in GPE, GPE, on DATE. Mr. PERSON, the former secretary of housing and urban development, would be one of the youngest presidents if elected.", "img_gen1": "DallE-GeneratedDataset/images/0_gen1.png", "original_caption2": "Julian Castro at his announcement in San Antonio, Tex., on Saturday, Jan. 12, 2019.", "caption2_mod": "PERSON at his announcement in GPE, GPE, on DATE.", "img_gen2": "DallE-GeneratedDataset/images/0_gen2.png", "label": 0}
# {"img_local_path": "test/1.jpg", "original_caption1": "Supporters of Tanzania's ruling Chama Cha Mapinduzi party come out on Friday to celebrate their candidate's victory in the disputed Zanzibari presidential election", "caption1_mod": "Supporters of GPE's ruling ORG party come out on DATE to celebrate their candidate's victory in the disputed PERSON presidential election", "img_gen1": "DallE-GeneratedDataset/images/1_gen1.png", "original_caption2": "A person sits on a truck as supporters of the ruling Chama Cha Mapinduzi (Revolutionary Party) celebrate the victory of their candidate in the Zanzibar Presidential election on the outskirts of Stone Town, on October 30, 2020.", "caption2_mod": "A person sits on a truck as supporters of the ruling PERSON (ORG) celebrate the victory of their candidate in the Zanzibar Presidential election on the outskirts of GPE, on DATE.", "img_gen2": "DallE-GeneratedDataset/images/1_gen2.png", "label": 0}
# {"img_local_path": "test/2.jpg", "original_caption1": "53,000 dead people turned up on the state\u2019s voter rolls in November 2018.", "caption1_mod": "CARDINAL dead people turned up on the state\u2019s voter rolls in DATE.", "img_gen1": "DallE-GeneratedDataset/images/2_gen1.png", "original_caption2": "These social media posts did not link to a recent article concerning the recount taking place in Florida in November 2018, but rather to a 6-year-old story about the impact of a new (and controversial) voter-related law which was originally published by Fox News back in 2013", "caption2_mod": "These social media posts did not link to a recent article concerning the recount taking place in GPE in DATE, but rather to a DATE story about the impact of a new (and controversial) voter-related law which was originally published by ORG back in DATE", "img_gen2": "DallE-GeneratedDataset/images/2_gen2.png", "label": 1}
# {"img_local_path": "test/3.jpg", "original_caption1": "Actor, musician, director and devoted follower of Christ, Kirk Cameron, has been stricken with an extremely rare form of what can only be described as a biblical disease.", "caption1_mod": "Actor, musician, director and devoted follower of ORG, PERSON, has been stricken with an extremely rare form of what can only be described as a biblical disease.", "img_gen1": "DallE-GeneratedDataset/images/3_gen1.png", "original_caption2": "A shocking report about the former child actor Kirk Cameron was just another hoax from a well-known purveyor of satire.", "caption2_mod": "A shocking report about the former child actor PERSON was just another hoax from a well-known purveyor of satire.", "img_gen2": "DallE-GeneratedDataset/images/3_gen2.png", "label": 1}
# {"img_local_path": "test/4.jpg", "original_caption1": "Men from the Maasai tribe perform a traditional jumping ritual as they observe a rite of passage to mark the transition to cultural junior elder within the Masai-Mara national reserve.", "caption1_mod": "Men from the GPE tribe perform a traditional jumping ritual as they observe a rite of passage to mark the transition to cultural junior elder within the ORG national reserve.", "img_gen1": "DallE-GeneratedDataset/images/4_gen1.png", "original_caption2": "And on the same day in Kenya's Narok county, young Masai men take part in initiation rites to become moran - the men who are traditionally the warrior class.", "caption2_mod": "And on DATE in GPE's GPE, young PERSON men take part in initiation rites to become moran - the men who are traditionally the warrior class.", "img_gen2": "DallE-GeneratedDataset/images/4_gen2.png", "label": 0}
# {"img_local_path": "test/5.jpg", "original_caption1": "An employee attaches \"skin\" to the head of a humanoid robot developed by Promobot, a service robotics manufacturer, in Vladivostok, Russia.", "caption1_mod": "An employee attaches \"skin\" to the head of a humanoid robot developed by ORG, a service robotics manufacturer, in GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/5_gen1.png", "original_caption2": "A person fits artificial skin on to the head of a robot", "caption2_mod": "A person fits artificial skin on to the head of a robot", "img_gen2": "DallE-GeneratedDataset/images/5_gen2.png", "label": 0}
# {"img_local_path": "test/6.jpg", "original_caption1": "A bird (variously described as a goose or a duck) helping to keep a puppy warm", "caption1_mod": "A bird (variously described as a goose or a duck) helping to keep a puppy warm", "img_gen1": "DallE-GeneratedDataset/images/6_gen1.png", "original_caption2": "It isn\u2019t unprecedented for birds and dogs to strike up friendships, thus claim is false", "caption2_mod": "It isn\u2019t unprecedented for birds and dogs to strike up friendships, thus claim is false", "img_gen2": "DallE-GeneratedDataset/images/6_gen2.png", "label": 1}
# {"img_local_path": "test/7.png", "original_caption1": "A photograph shows Ricky Ellsworth, a white woman who was killed by a black police officer in Minnesota.", "caption1_mod": "A photograph shows PERSON, a white woman who was  by a black police officer in GPE.", "img_gen1": "DallE-GeneratedDataset/images/7_gen1.png", "original_caption2": "A viral meme got key facts wrong while attempting to make a point about police violence and racial injustice in the U.S.", "caption2_mod": "A viral meme got key facts wrong while attempting to make a point about police violence and  injustice in the GPE", "img_gen2": "DallE-GeneratedDataset/images/7_gen2.png", "label": 1}
# {"img_local_path": "test/8.png", "original_caption1": "A photograph shows a 9-year-old girl who was impregnated by a Muslim man.", "caption1_mod": "A photograph shows a DATE girl who was d by a NORP man.", "img_gen1": "DallE-GeneratedDataset/images/8_gen1.png", "original_caption2": "This image does not show a pregnant child. This photograph was originally posted by the Garraf\u00e3o do Norte Facebook page in November 2016 and shows a 12-year-old girl named Sandy at a hospital in Bel\u00e9m, Brazil.", "caption2_mod": "This image does not show a  child. This photograph was originally posted by the Garraf\u00e3o do ORG page in DATE and shows a DATE girl named PERSON at a hospital in GPE, GPE.", "img_gen2": "DallE-GeneratedDataset/images/8_gen2.png", "label": 1}
# {"img_local_path": "test/9.jpg", "original_caption1": "A man brushes the mouth of a sarcophagus.", "caption1_mod": "A man brushes the mouth of a sarcophagus.", "img_gen1": "DallE-GeneratedDataset/images/9_gen1.png", "original_caption2": "More than 40 statues of ancient deities and funerary masks were also discovered at the site, many of which still with their original colours and designs preserved", "caption2_mod": "CARDINAL statues of ancient deities and funerary masks were also discovered at the site, many of which still with their original colours and designs preserved", "img_gen2": "DallE-GeneratedDataset/images/9_gen2.png", "label": 0}
# {"img_local_path": "test/10.jpg", "original_caption1": "President Trump on Thursday visited the southern border in McAllen, Tex.", "caption1_mod": "President PERSON on DATE visited the southern border in GPE, PERSON.", "img_gen1": "DallE-GeneratedDataset/images/10_gen1.png", "original_caption2": "President Trump in McAllen, Tex., on the border with Mexico, in January. ", "caption2_mod": "President PERSON in GPE, GPE, on the border with GPE, in DATE. ", "img_gen2": "DallE-GeneratedDataset/images/10_gen2.png", "label": 0}
# {"img_local_path": "test/11.jpg", "original_caption1": "In Bangkok, tuk-tuks that used to transport tourists around the city are seen idle because of travel bans and border closures during the pandemic.", "caption1_mod": "In GPE, tuk-tuks that used to transport tourists around the city are seen idle because of travel bans and border closures during the pandemic.", "img_gen1": "DallE-GeneratedDataset/images/11_gen1.png", "original_caption2": "Tuk-tuk car parked in Bangkok because there are no tourists", "caption2_mod": "PERSON car parked in GPE because there are no tourists", "img_gen2": "DallE-GeneratedDataset/images/11_gen2.png", "label": 0}
# {"img_local_path": "test/12.jpg", "original_caption1": "Castle Square, also known as the \"Hole in the Road\", 1989", "caption1_mod": "FAC, also known as the \"WORK_OF_ART\", DATE", "img_gen1": "DallE-GeneratedDataset/images/12_gen1.png", "original_caption2": "Castle Square, Sheffield, 1989", "caption2_mod": "FAC, GPE, 1989", "img_gen2": "DallE-GeneratedDataset/images/12_gen2.png", "label": 0}
# {"img_local_path": "test/13.jpg", "original_caption1": "Shoppers in an Istanbul market", "caption1_mod": "Shoppers in an GPE market", "img_gen1": "DallE-GeneratedDataset/images/13_gen1.png", "original_caption2": "A street vendor sells traditional Turkish backery \"Simit\" as people shop near the New Mosque area in Istanbul's Eminonu district on November 6, 2018.", "caption2_mod": "A street vendor sells traditional NORP backery \"Simit\" as people shop near the GPE area in GPE's GPE district on DATE.", "img_gen2": "DallE-GeneratedDataset/images/13_gen2.png", "label": 0}
# {"img_local_path": "test/14.jpg", "original_caption1": "U.S. President Donald Trump tweeted that, \"Anyone who ordered a ticket to my rally and didn't attend should be arrested and face very powerful charges.\"", "caption1_mod": "GPE President PERSON tweeted that, \"Anyone who ordered a ticket to my rally and didn't attend should be arrested and face very powerful charges.\"", "img_gen1": "DallE-GeneratedDataset/images/14_gen1.png", "original_caption2": "The image claiming ordering a ticket to Trump's rally and arrest on not attending was a fabrication, intended as a spoof poking fun at the president over the disappointing rally attendance.", "caption2_mod": "The image claiming ordering a ticket to ORG's rally and arrest on not attending was a fabrication, intended as a spoof poking fun at the president over the disappointing rally attendance.", "img_gen2": "DallE-GeneratedDataset/images/14_gen2.png", "label": 1}
# {"img_local_path": "test/15.jpg", "original_caption1": "Thunberg already has several murals around the world, this one in San Francisco", "caption1_mod": "Thunberg already has several murals around the world, this one in GPE", "img_gen1": "DallE-GeneratedDataset/images/15_gen1.png", "original_caption2": "San Francisco's latest mural features famous climate activist Greta Thunberg", "caption2_mod": "GPE latest mural features famous climate activist PERSON", "img_gen2": "DallE-GeneratedDataset/images/15_gen2.png", "label": 0}
# {"img_local_path": "test/16.jpg", "original_caption1": "On the same day in South Africa, a bird walks along Durban's empty shore where a ban on gatherings kept revellers at bay.", "caption1_mod": "On DATE in GPE, a bird walks along Durban's empty shore where a ban on gatherings kept revellers at bay.", "img_gen1": "DallE-GeneratedDataset/images/16_gen1.png", "original_caption2": "General view of an empty beach with high-rise buildings in the distance.", "caption2_mod": "General view of an empty beach with high-rise buildings in the distance.", "img_gen2": "DallE-GeneratedDataset/images/16_gen2.png", "label": 0}
# {"img_local_path": "test/17.jpg", "original_caption1": "This woman, dressed in the colours of the Nigerian flag, takes part in the celebrations at Abuja's Eagle Square...", "caption1_mod": "This woman, dressed in the colours of the NORP flag, takes part in the celebrations at LOC's FAC...", "img_gen1": "DallE-GeneratedDataset/images/17_gen1.png", "original_caption2": "Independence Band performance at the Eagles Square in Abuja, Nigeria during the country's 60th Independence Celebration on October 1, 2020", "caption2_mod": "Independence Band performance at FAC in GPE during the country's ORDINAL EVENT on DATE", "img_gen2": "DallE-GeneratedDataset/images/17_gen2.png", "label": 0}
# {"img_local_path": "test/18.jpg", "original_caption1": "A man diving into water from a height into the Neretva river in Mostar", "caption1_mod": "A man diving into water from a height into LOC in GPE", "img_gen1": "DallE-GeneratedDataset/images/18_gen1.png", "original_caption2": "A man jumps from the Old Bridge into the Neretva river during the 454th traditional diving competition in Mostar, Bosnia-Herzegovina.", "caption2_mod": "A man jumps from FAC into the LOC river during the NORP traditional diving competition in GPE, GPE.", "img_gen2": "DallE-GeneratedDataset/images/18_gen2.png", "label": 0}
# {"img_local_path": "test/19.jpg", "original_caption1": "Asylum seekers lining up last week in Tijuana, Mexico.", "caption1_mod": "Asylum seekers lining up DATE in GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/19_gen1.png", "original_caption2": "Asylum seekers lined up in January outside the El Chaparral entry point into the United States in Tijuana, Mexico.", "caption2_mod": "Asylum seekers lined up in DATE outside the ORG entry point into GPE in GPE, GPE.", "img_gen2": "DallE-GeneratedDataset/images/19_gen2.png", "label": 0}
# {"img_local_path": "test/20.jpg", "original_caption1": "Martin Fayulu, the opposition leader and runner-up in the election, had demanded a manual recount of the results.", "caption1_mod": "PERSON, the opposition leader and runner-up in the election, had demanded a manual recount of the results.", "img_gen1": "DallE-GeneratedDataset/images/20_gen1.png", "original_caption2": "Opposition presidential candidate in the Democratic Republic of Congo Martin Fayulu walks outside the constitutional court in the capital, Kinshasa on January 12, 2019, as he filed his appeal to impose a recount of the votes in the presidential election following a suspicion of fraud.", "caption2_mod": "Opposition presidential candidate in GPE Martin Fayulu walks outside the constitutional court in the capital, ORG on DATE, as he filed his appeal to impose a recount of the votes in the presidential election following a suspicion of fraud.", "img_gen2": "DallE-GeneratedDataset/images/20_gen2.png", "label": 0}
# {"img_local_path": "test/21.jpg", "original_caption1": "A tribute to Captain Sir Tom Moore lights up Piccadilly Circus, London. The 100-year-old, who raised almost PS33m for NHS charities by walking laps of his garden, died with coronavirus.", "caption1_mod": "A tribute to Captain Sir PERSON lights up ORG, GPE. The DATE, who raised almost PS33m for ORG charities by walking laps of his garden,  with .", "img_gen1": "DallE-GeneratedDataset/images/21_gen1.png", "original_caption2": "A woman plays the violin in Piccadilly Circus during a tribute to Captain Sir Tom Moore on 2 February 2021", "caption2_mod": "A woman plays the violin in ORG during a tribute to Captain Sir PERSON on DATE", "img_gen2": "DallE-GeneratedDataset/images/21_gen2.png", "label": 0}
# {"img_local_path": "test/22.jpg", "original_caption1": "cockapoo, Bailey, during his morning walk in London's Regent's Park", "caption1_mod": "PERSON, PERSON, during his TIME walk in GPE's FAC", "img_gen1": "DallE-GeneratedDataset/images/22_gen1.png", "original_caption2": "Bailey the cockapoo in London's Regent's Park", "caption2_mod": "Bailey the cockapoo in GPE's FAC", "img_gen2": "DallE-GeneratedDataset/images/22_gen2.png", "label": 0}
# {"img_local_path": "test/23.png", "original_caption1": "A video shows people in China tearing down a 5G tower in an attempt to stop the spread of COVID-19 coronavirus disease.", "caption1_mod": "A video shows people in GPE tearing down a CARDINALG tower in an attempt to stop the spread of   disease.", "img_gen1": "DallE-GeneratedDataset/images/23_gen1.png", "original_caption2": "The video shows protesters in Hong Kong in August 2019 (before the COVID-19 pandemic) tearing down a surveillance tower.", "caption2_mod": "The video shows protesters in GPE in DATE (before the  pandemic) tearing down a surveillance tower.", "img_gen2": "DallE-GeneratedDataset/images/23_gen2.png", "label": 1}
# {"img_local_path": "test/24.jpg", "original_caption1": "Supporters of Spain's far-right Vox party in Seville, celebrating the results of regional elections in Andalusia last month.", "caption1_mod": "Supporters of GPE's far-right ORG in GPE, celebrating the results of regional elections in GPE DATE.", "img_gen1": "DallE-GeneratedDataset/images/24_gen1.png", "original_caption2": "Supporters of Spain's anti-immigrant, populist Vox party, which won 12 seats in recent elections - its first in any Spanish legislative body.", "caption2_mod": "Supporters of GPE's anti-immigrant, populist PERSON, which won CARDINAL seats in recent elections - its ORDINAL in any NORP legislative body.", "img_gen2": "DallE-GeneratedDataset/images/24_gen2.png", "label": 0}
# {"img_local_path": "test/25.jpg", "original_caption1": "NASA warned that Asteroid 52768 (1998 OR2) could hit Earth in April 2020 and cause catastrophic danger.", "caption1_mod": "ORG warned that DATE (1998 OR2) could hit LOC in DATE and cause catastrophic danger.", "img_gen1": "DallE-GeneratedDataset/images/25_gen1.png", "original_caption2": "This image of asteroid Eros, taken by NASA's NEAR Shoemaker on Feb. 29, 2000, shows the north polar region highlighting the major physiographic features of the northern hemisphere; the saddle seen at the bottom.", "caption2_mod": "This image of asteroid NORP, taken by ORG's LOC on DATE, shows the north polar region highlighting the major physiographic features of LOC; the saddle seen at the bottom.", "img_gen2": "DallE-GeneratedDataset/images/25_gen2.png", "label": 1}
# {"img_local_path": "test/26.jpg", "original_caption1": "A photograph shows a Southeast African monkey from Madagascar.", "caption1_mod": "A photograph shows a NORP monkey from GPE.", "img_gen1": "DallE-GeneratedDataset/images/26_gen1.png", "original_caption2": "This photograph, however, does not capture an unusual primate from Madagascar. Instead, it depicts a doll from the \u201cInari Foxes\u201d collection produced by the Santani Workshop in Russia.", "caption2_mod": "This photograph, however, does not capture an unusual primate from GPE. Instead, it depicts a doll from the \u201cInari Foxes\u201d collection produced by PERSON in GPE.", "img_gen2": "DallE-GeneratedDataset/images/26_gen2.png", "label": 1}
# {"img_local_path": "test/27.jpg", "original_caption1": "Humanoid robots with hyper-realistic skin are being developed  by Promobot service robotics manufacturer at the company's branch in the far eastern city of Vladivostok, Russia", "caption1_mod": "Humanoid robots with hyper-realistic skin are being developed  by GPE service robotics manufacturer at the company's branch in the far eastern city of GPE, GPE", "img_gen1": "DallE-GeneratedDataset/images/27_gen1.png", "original_caption2": "An employee attaches \"skin\" to the head of a humanoid robot developed by Promobot, a service robotics manufacturer, in Vladivostok, Russia.", "caption2_mod": "An employee attaches \"skin\" to the head of a humanoid robot developed by ORG, a service robotics manufacturer, in GPE, GPE.", "img_gen2": "DallE-GeneratedDataset/images/27_gen2.png", "label": 0}
# {"img_local_path": "test/28.jpg", "original_caption1": "On Tuesday police patrol the school where more than 300 children were kidnapped in Katsina state, northern Nigeria...", "caption1_mod": "On DATE police patrol the school where CARDINAL children were kidnapped in GPE state, northern GPE...", "img_gen1": "DallE-GeneratedDataset/images/28_gen1.png", "original_caption2": "Police patrol inside the Government Science school in Kankara, in northwestern Katsina state, Nigeria after gunmen abducted students on December 15, 2020.", "caption2_mod": "Police patrol inside the ORG school in GPE, in northwestern GPE state, GPE after gunmen abducted students on DATE.", "img_gen2": "DallE-GeneratedDataset/images/28_gen2.png", "label": 0}
# {"img_local_path": "test/29.jpg", "original_caption1": "A federal gun law was passed in September 2016 which will prevent people from practicing \"open carry\" in all 50 states.", "caption1_mod": "A federal gun law was passed in DATE which will prevent people from practicing \"open carry\" in all CARDINAL states.", "img_gen1": "DallE-GeneratedDataset/images/29_gen1.png", "original_caption2": "An open carry advocate walks down the street in Austin, Texas.", "caption2_mod": "An open carry advocate walks down the street in GPE, GPE.", "img_gen2": "DallE-GeneratedDataset/images/29_gen2.png", "label": 1}
# {"img_local_path": "test/30.jpg", "original_caption1": "Maine lobsterman catches extremely rare purple lobster", "caption1_mod": "GPE lobsterman catches extremely rare purple lobster", "img_gen1": "DallE-GeneratedDataset/images/30_gen1.png", "original_caption2": "These are not genuine photographs of a purple lobster.", "caption2_mod": "These are not genuine photographs of a purple lobster.", "img_gen2": "DallE-GeneratedDataset/images/30_gen2.png", "label": 1}
# {"img_local_path": "test/31.jpg", "original_caption1": "A ZIP code in Brooklyn has N.Y.C.\u2019s highest death rate.", "caption1_mod": "A ZIP code in GPE has GPE\u2019s highest  rate.", "img_gen1": "DallE-GeneratedDataset/images/31_gen1.png", "original_caption2": "Trinseo is a global leader in supplying synthetic rubber products and services.", "caption2_mod": "Trinseo is a global leader in supplying synthetic rubber products and services.", "img_gen2": "DallE-GeneratedDataset/images/31_gen2.png", "label": 1}
# {"img_local_path": "test/32.jpg", "original_caption1": "U.S. Secretary of State Mike Pompeo on Thursday during a tour of a mosque in Egypt's new administrative capital, east of Cairo.", "caption1_mod": "GPE Secretary of ORG PERSON on DATE during a tour of a mosque in GPE's new administrative capital, east of GPE.", "img_gen1": "DallE-GeneratedDataset/images/32_gen1.png", "original_caption2": "U.S. Secretary of State Mike Pompeo, center, speaks to the press during a tour of the newly inaugurated Al-Fattah Al-Alim mosque in Egypt\u2019s new administrative capital, east of Cairo, on Jan. 10, 2019", "caption2_mod": "GPE Secretary of ORG PERSON, center, speaks to the press during a tour of the newly inaugurated PERSON in GPE\u2019s new administrative capital, east of GPE, on DATE", "img_gen2": "DallE-GeneratedDataset/images/32_gen2.png", "label": 0}
# {"img_local_path": "test/33.jpg", "original_caption1": "Actor Will Smith and his son, rapper Jaden Smith, had \u201cdied in a crash after a \u201ccar and truck collision\u201d", "caption1_mod": "Actor PERSON and his son, rapper PERSON, had \u201c in a crash after a \u201ccar and truck collision\u201d", "img_gen1": "DallE-GeneratedDataset/images/33_gen1.png", "original_caption2": "This post was a hoax, as neither Will nor Jaden Smith had died or been seriously injured in an automobile accident.", "caption2_mod": "This post was a hoax, as neither Will nor PERSON had  or been seriously injured in an automobile accident.", "img_gen2": "DallE-GeneratedDataset/images/33_gen2.png", "label": 1}
# {"img_local_path": "test/34.jpg", "original_caption1": "A man dives into the water near Canary Wharf, London.", "caption1_mod": "A man dives into the water near GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/34_gen1.png", "original_caption2": "A man dives into water in the London Docklands, as two other men in inflatable boats watch", "caption2_mod": "A man dives into water in the GPE Docklands, as CARDINAL other men in inflatable boats watch", "img_gen2": "DallE-GeneratedDataset/images/34_gen2.png", "label": 0}
# {"img_local_path": "test/35.jpg", "original_caption1": "Traffic on the railway between Ivory Coast's biggest city, Abidjan, and Ouagadougou, the capital of Burkina Faso, was halted on Friday after a landslide", "caption1_mod": "Traffic on the railway between GPE biggest city, GPE, and PERSON, the capital of PERSON, was halted on DATE after a landslide", "img_gen1": "DallE-GeneratedDataset/images/35_gen1.png", "original_caption2": "A suspended railway track at the site of a landslide that killed 13 people the day before, in Anyama, near Abidjan -19 June 2020", "caption2_mod": "A suspended railway track at the site of a landslide that  CARDINAL people DATE, in GPE, near GPE -19 DATE", "img_gen2": "DallE-GeneratedDataset/images/35_gen2.png", "label": 0}
# {"img_local_path": "test/36.jpg", "original_caption1": "The Annabelle doll escaped from the Warren's Occult Museum in Connecticut.", "caption1_mod": "The PERSON doll escaped from the PERSON's ORG in GPE.", "img_gen1": "DallE-GeneratedDataset/images/36_gen1.png", "original_caption2": "Sources confirmed that Annabelle did not escape. Annabelle\u2019s alive in all her Warren's Museum infamous glory. She never left the museum.\u201d", "caption2_mod": "Sources confirmed that PERSON did not escape. PERSON\u2019s alive in all her PERSON's Museum infamous glory. She never left the museum.\u201d", "img_gen2": "DallE-GeneratedDataset/images/36_gen2.png", "label": 1}
# {"img_local_path": "test/37.jpg", "original_caption1": "Are These Towering Snow Walls in Massachusetts", "caption1_mod": "Are These Towering  Walls in GPE", "img_gen1": "DallE-GeneratedDataset/images/37_gen1.png", "original_caption2": "The journey of Tateyama Kurobe in Japan", "caption2_mod": "The journey of PERSON in GPE", "img_gen2": "DallE-GeneratedDataset/images/37_gen2.png", "label": 1}
# {"img_local_path": "test/38.png", "original_caption1": "Setting your Apple device's date to 1 January 1970 will reveal a retro-themed Easter egg.", "caption1_mod": "Setting your ORG device's date to CARDINAL DATE will reveal a retro-themed FAC.", "img_gen1": "DallE-GeneratedDataset/images/38_gen1.png", "original_caption2": "Never put January 1, 1970 as the date on your iPhone, unless you want to block it", "caption2_mod": "Never put DATE as the date on your iPhone, unless you want to block it", "img_gen2": "DallE-GeneratedDataset/images/38_gen2.png", "label": 1}
# {"img_local_path": "test/39.jpg", "original_caption1": "Some 53,000 dead people were found to be included in Florida's voter rolls in November 2018.", "caption1_mod": "Some CARDINAL dead people were found to be included in GPE's voter rolls in DATE.", "img_gen1": "DallE-GeneratedDataset/images/39_gen1.png", "original_caption2": "These social media posts did not link to a recent article concerning the recount taking place in Florida in November 2018, but rather to a 6-year-old story about the impact of a new (and controversial) voter-related law which was originally published by Fox News back in 2012", "caption2_mod": "These social media posts did not link to a recent article concerning the recount taking place in GPE in DATE, but rather to a DATE story about the impact of a new (and controversial) voter-related law which was originally published by ORG back in DATE", "img_gen2": "DallE-GeneratedDataset/images/39_gen2.png", "label": 1}
# {"img_local_path": "test/40.jpg", "original_caption1": "Snopes.com ignored reports of a large child trafficking ring bust in Arizona.", "caption1_mod": "ORG ignored reports of a large child  ring bust in GPE.", "img_gen1": "DallE-GeneratedDataset/images/40_gen1.png", "original_caption2": "A black and white image of hands being tied together with rope.", "caption2_mod": "A black and white image of hands being tied together with rope.", "img_gen2": "DallE-GeneratedDataset/images/40_gen2.png", "label": 1}
# {"img_local_path": "test/41.jpg", "original_caption1": "Thousands flocked to a volcano in Iceland which erupted near the capital, Reykjavik.", "caption1_mod": "CARDINAL flocked to a volcano in GPE which erupted near the capital, GPE.", "img_gen1": "DallE-GeneratedDataset/images/41_gen1.png", "original_caption2": "Volcano erupts in Iceland", "caption2_mod": "Volcano erupts in GPE", "img_gen2": "DallE-GeneratedDataset/images/41_gen2.png", "label": 0}
# {"img_local_path": "test/42.jpg", "original_caption1": "Yoga teacher Harriet McAtee conducts a yoga class on her 6ft (1.8m)-wide narrowboat in Oxford.", "caption1_mod": "Yoga teacher PERSON conducts a yoga class on her QUANTITY (QUANTITY narrowboat in GPE.", "img_gen1": "DallE-GeneratedDataset/images/42_gen1.png", "original_caption2": "A woman holds a yoga pose in her narrowboat", "caption2_mod": "A woman holds a yoga pose in her narrowboat", "img_gen2": "DallE-GeneratedDataset/images/42_gen2.png", "label": 0}
# {"img_local_path": "test/43.jpg", "original_caption1": "Detainees sleeping in the Manila City Jail in the Philippines.", "caption1_mod": "Detainees sleeping in FAC in the GPE.", "img_gen1": "DallE-GeneratedDataset/images/43_gen1.png", "original_caption2": "Detainees are seen sleeping by a small grotto of Mary in the Manila City Jail.", "caption2_mod": "Detainees are seen sleeping by a small grotto of PERSON in GPE Jail.", "img_gen2": "DallE-GeneratedDataset/images/43_gen2.png", "label": 0}
# {"img_local_path": "test/44.jpg", "original_caption1": "The National Cancer Institute has \"admitted\" that \"cannabis kills cancer.\"", "caption1_mod": "ORG has \"admitted\" that \"cannabis  cancer.\"", "img_gen1": "DallE-GeneratedDataset/images/44_gen1.png", "original_caption2": "There is no evidence in any way to \u201cprove\u201d that cannabis could be a viable treatment for cancer, we rank this claim as false.", "caption2_mod": "There is no evidence in any way to \u201cprove\u201d that cannabis could be a viable treatment for cancer, we rank this claim as false.", "img_gen2": "DallE-GeneratedDataset/images/44_gen2.png", "label": 1}
# {"img_local_path": "test/45.jpg", "original_caption1": "A metro train in the city of Spijkenisse, in the Netherlands, rests precariously on an art installation of a whale after crashing through a barrier at the end of the tracks.", "caption1_mod": "A metro train in the city of PRODUCT, in the GPE, rests precariously on an art installation of a whale after crashing through a barrier at the end of the tracks.", "img_gen1": "DallE-GeneratedDataset/images/45_gen1.png", "original_caption2": "A metro train rests precariously on an art installation of a whale in Spijkenisse, near Rotterdam, Netherlands, 2 November 2020", "caption2_mod": "A metro train rests precariously on an art installation of a whale in GPE, near GPE, GPE, CARDINAL November 2020", "img_gen2": "DallE-GeneratedDataset/images/45_gen2.png", "label": 0}
# {"img_local_path": "test/46.jpg", "original_caption1": "An Omagh plumber tunnelled a hole from under his bed to the local pub 800 feet from his house over the course of 15 years, a court heard today.", "caption1_mod": "An Omagh plumber tunnelled a hole from under his bed to the local pub QUANTITY from his house over the course of DATE, a court heard DATE.", "img_gen1": "DallE-GeneratedDataset/images/46_gen1.png", "original_caption2": "The Irish man digging the tunnel unwittingly fooled thousands of people", "caption2_mod": "The NORP man digging the tunnel unwittingly fooled CARDINAL of people", "img_gen2": "DallE-GeneratedDataset/images/46_gen2.png", "label": 1}
# {"img_local_path": "test/47.png", "original_caption1": "A 29-year old Calgary local has suffered extensive injuries to his lower body after an unconventional attempt to \u2018fill a scuba tank with weed smoke\u2019 failed spectacularly last Thursday night.", "caption1_mod": "A DATE GPE local has suffered extensive injuries to his lower body after an unconventional attempt to \u2018fill a scuba tank with  smoke\u2019 failed spectacularly DATE TIME.", "img_gen1": "DallE-GeneratedDataset/images/47_gen1.png", "original_caption2": "The photograph of the ruptured scuba tank has been circulating since at least 2008, and the image of the ambulance was taken in 2015 after an assault in Calgary.", "caption2_mod": "The photograph of the ruptured scuba tank has been circulating since DATE, and the image of the ambulance was taken in DATE after an assault in GPE.", "img_gen2": "DallE-GeneratedDataset/images/47_gen2.png", "label": 1}
# {"img_local_path": "test/48.jpg", "original_caption1": "The Cow and the Tailor Shop, Rajasthan, by Elizabeth Brooks, from the US", "caption1_mod": "The Cow and the Tailor Shop, PERSON, by PERSON, from the GPE", "img_gen1": "DallE-GeneratedDataset/images/48_gen1.png", "original_caption2": "A sacred cow in a street in India", "caption2_mod": "A sacred cow in a street in GPE", "img_gen2": "DallE-GeneratedDataset/images/48_gen2.png", "label": 0}
# {"img_local_path": "test/49.jpg", "original_caption1": "The FBI raided the CDC in the middle of the night to seize data on a link between vaccines and autism.", "caption1_mod": "The ORG raided the ORG in TIME to seize data on a link between vaccines and autism.", "img_gen1": "DallE-GeneratedDataset/images/49_gen1.png", "original_caption2": "A known hoax purveyor spread false claims that the FBI \"raided\" the CDC in the middle of the night for data on vaccines and autism on the order of President Trump.", "caption2_mod": "A known hoax purveyor spread false claims that the ORG \"raided\" the ORG in TIME for data on vaccines and autism on the order of President PERSON.", "img_gen2": "DallE-GeneratedDataset/images/49_gen2.png", "label": 1}
# {"img_local_path": "test/50.jpg", "original_caption1": "Kenyan fashion-lover James Maina Mwangi, who once told the BBC he was Africa's most stylish man, poses with some of his pieces on Friday.", "caption1_mod": "NORP fashion-lover PERSON, who once told the ORG he was LOC's most stylish man, poses with some of his pieces on DATE.", "img_gen1": "DallE-GeneratedDataset/images/50_gen1.png", "original_caption2": "Kenyan fashionista James Maina Mwangi, dressed all in purple, stands beside green, yellow and red suits.", "caption2_mod": "NORP fashionista PERSON, dressed all in purple, stands beside green, yellow and red suits.", "img_gen2": "DallE-GeneratedDataset/images/50_gen2.png", "label": 0}
# {"img_local_path": "test/51.jpg", "original_caption1": "The British Parliament's famous clock tower is being renovated.", "caption1_mod": "ORG famous clock tower is being renovated.", "img_gen1": "DallE-GeneratedDataset/images/51_gen1.png", "original_caption2": "Tourists click photographs of the clock tower ", "caption2_mod": "Tourists click photographs of the clock tower ", "img_gen2": "DallE-GeneratedDataset/images/51_gen2.png", "label": 0}
# {"img_local_path": "test/52.jpg", "original_caption1": "Lex Scott Davis and Trevor Jackson in \"Superfly.\"", "caption1_mod": "PERSON and PERSON in \"WORK_OF_ART.\"", "img_gen1": "DallE-GeneratedDataset/images/52_gen1.png", "original_caption2": "Trevor Jackson (right) plays a suave drug dealer named Priest and Lex Scott Davis is Georgia in SuperFly, Director X\u2019s blinged-out redo of the 1972 blaxploitation classic.", "caption2_mod": "PERSON (right) plays a suave drug dealer named PERSON and PERSON is GPE in ORG, Director PERSON\u2019s blinged-out redo of the DATE blaxploitation classic.", "img_gen2": "DallE-GeneratedDataset/images/52_gen2.png", "label": 0}
# {"img_local_path": "test/53.png", "original_caption1": "A photograph shows a genuine fossil of a megalodon tooth embedded in a whale bone.", "caption1_mod": "A photograph shows a genuine fossil of a megalodon tooth embedded in a whale bone.", "img_gen1": "DallE-GeneratedDataset/images/53_gen1.png", "original_caption2": "While this image likely shows a genuine megalodon tooth as well as a genuine whale bone, these two artifacts were not discovered at the same time, in the same location, or in this particular arrangement.", "caption2_mod": "While this image likely shows a genuine megalodon tooth as well as a genuine whale bone, these CARDINAL artifacts were not discovered at the same time, in the same location, or in this particular arrangement.", "img_gen2": "DallE-GeneratedDataset/images/53_gen2.png", "label": 1}
# {"img_local_path": "test/54.jpg", "original_caption1": "British Prime Minister Theresa May addresses the media outside 10 Downing Street, January 16, 2019", "caption1_mod": "NORP Prime Minister PERSON addresses the media outside LOC, DATE", "img_gen1": "DallE-GeneratedDataset/images/54_gen1.png", "original_caption2": "Prime minister Theresa May delivers a statement to members of the media in Downing Street after surviving a vote of no confidence in her government. May remained as prime minister after weathering the dramatic no-confidence vote , but was left scrambling to strike a Brexit compromise that could secure the backing of parliament. In her statement, the prime minister exhorted politicians from all parties to \u2018put aside self-interest\u2019, and promised to consult with MPs with \u2018the widest possible range of views\u2019.", "caption2_mod": "Prime minister PERSON delivers a statement to members of the media in FAC after surviving a vote of no confidence in her government. DATE remained as prime minister after weathering the dramatic no-confidence vote , but was left scrambling to strike a GPE compromise that could secure the backing of parliament. In her statement, the prime minister exhorted politicians from all parties to \u2018put aside self-interest\u2019, and promised to consult with MPs with \u2018the widest possible range of views\u2019.", "img_gen2": "DallE-GeneratedDataset/images/54_gen2.png", "label": 0}
# {"img_local_path": "test/55.jpg", "original_caption1": "Trash being left behind by the migrant caravan.", "caption1_mod": "Trash being left behind by the migrant caravan.", "img_gen1": "DallE-GeneratedDataset/images/55_gen1.png", "original_caption2": "This photograph was not recent and did not show refuse left behind by the caravan of refugees traveling from Honduras to the U.S-Mexico border in October 2018.", "caption2_mod": "This photograph was not recent and did not show refuse left behind by the caravan of refugees traveling from GPE to the GPE-GPE border in DATE.", "img_gen2": "DallE-GeneratedDataset/images/55_gen2.png", "label": 1}
# {"img_local_path": "test/56.jpg", "original_caption1": "A giraffe crosses a road laced with an electric fence within the Kimana Sanctuary within the Amboseli ecosystem in Kimana", "caption1_mod": "A giraffe crosses a road laced with an electric fence within the GPE Sanctuary within the Amboseli ecosystem in Kimana", "img_gen1": "DallE-GeneratedDataset/images/56_gen1.png", "original_caption2": "A giraffe crosses a road laced with an electric fences.", "caption2_mod": "A giraffe crosses a road laced with an electric fences.", "img_gen2": "DallE-GeneratedDataset/images/56_gen2.png", "label": 0}
# {"img_local_path": "test/57.jpg", "original_caption1": "An image shows a mural painted in 1994 at Denver International Airport that shows citizens of the world wearing masks.", "caption1_mod": "An image shows a mural painted in DATE at FAC that shows citizens of the world wearing masks.", "img_gen1": "DallE-GeneratedDataset/images/57_gen1.png", "original_caption2": "This viral image does not show a mural that was painted at the Denver International Airport in 1994. This image shows a modern day artwork that was likely created by CJ Trinidad.", "caption2_mod": "This viral image does not show a mural that was painted at FAC in DATE. This image shows a DATE artwork that was likely created by CJ Trinidad.", "img_gen2": "DallE-GeneratedDataset/images/57_gen2.png", "label": 1}
# {"img_local_path": "test/58.jpg", "original_caption1": "And on Wednesday, cars wait patiently for a giraffe to cross the road in Kenya's Kimana Sanctuary.", "caption1_mod": "And on DATE, cars wait patiently for a giraffe to cross the road in GPE's GPE.", "img_gen1": "DallE-GeneratedDataset/images/58_gen1.png", "original_caption2": "A giraffe crosses a road laced with an electric fences.", "caption2_mod": "A giraffe crosses a road laced with an electric fences.", "img_gen2": "DallE-GeneratedDataset/images/58_gen2.png", "label": 0}
# {"img_local_path": "test/59.jpg", "original_caption1": "Gill Mackintosh spotted this sheep in a bus shelter on a drive out to Huisinish point on North Harris.", "caption1_mod": "PERSON spotted this sheep in a bus shelter on a drive out to NORP point on LOC.", "img_gen1": "DallE-GeneratedDataset/images/59_gen1.png", "original_caption2": "Sheep in a bus shelter", "caption2_mod": "Sheep in a bus shelter", "img_gen2": "DallE-GeneratedDataset/images/59_gen2.png", "label": 0}
# {"img_local_path": "test/60.png", "original_caption1": "Sex Traffickers in Florida Trick Motorists By Lying in the Road.", "caption1_mod": " Traffickers in GPE Trick Motorists By Lying in the Road.", "img_gen1": "DallE-GeneratedDataset/images/60_gen1.png", "original_caption2": "No evidence was found that the photographs included in the November and December 2019 Facebook posts showed a specific incident of attempted sex trafficking.", "caption2_mod": "No evidence was found that the photographs included in the DATE ORG posts showed a specific incident of attempted  .", "img_gen2": "DallE-GeneratedDataset/images/60_gen2.png", "label": 1}
# {"img_local_path": "test/61.png", "original_caption1": "A video supposedly showing an unusually large snare swimming across a river in Brazil", "caption1_mod": "A video supposedly showing an unusually large snare swimming across a river in GPE", "img_gen1": "DallE-GeneratedDataset/images/61_gen1.png", "original_caption2": "This video has been severely distorted to make this snake appear much larger.", "caption2_mod": "This video has been severely distorted to make this snake appear much larger.", "img_gen2": "DallE-GeneratedDataset/images/61_gen2.png", "label": 1}
# {"img_local_path": "test/62.jpg", "original_caption1": "Rescue workers at the site of a train accident on Great Belt Bridge in Nyborg, Denmark.", "caption1_mod": "Rescue workers at the site of a train accident on FAC in GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/62_gen1.png", "original_caption2": "The passenger train that was struck by a cargo container in Denmark early Wednesday", "caption2_mod": "The passenger train that was struck by a cargo container in GPE TIME", "img_gen2": "DallE-GeneratedDataset/images/62_gen2.png", "label": 0}
# {"img_local_path": "test/63.jpg", "original_caption1": "Rescue workers at the site of a train accident on Great Belt Bridge in Nyborg, Denmark.", "caption1_mod": "Rescue workers at the site of a train accident on FAC in GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/63_gen1.png", "original_caption2": "Emergency crews work at the site of a train accident that killed at least six people Wednesday in Nyborg, Denmark. The accident took place on one of the bridges in the Storebaelt system, also known as the Great Belt link.", "caption2_mod": "Emergency crews work at the site of a train accident that  CARDINAL people DATE in GPE, GPE. The accident took place on one of the bridges in the PERSON system, also known as the FAC link.", "img_gen2": "DallE-GeneratedDataset/images/63_gen2.png", "label": 0}
# {"img_local_path": "test/64.jpg", "original_caption1": "Indian paramilitary troops in Srinagar in Kashmir this month. Sixty eight percent of the army's equipment is so old that it is officially considered \"vintage.\"", "caption1_mod": "NORP paramilitary troops in GPE in GPE DATE. PERCENT of the army's equipment is so old that it is officially considered \"vintage.\"", "img_gen1": "DallE-GeneratedDataset/images/64_gen1.png", "original_caption2": "Kashmir braces for worst as shelling, gunbattles escalate", "caption2_mod": "Kashmir braces for worst as shelling, gunbattles escalate", "img_gen2": "DallE-GeneratedDataset/images/64_gen2.png", "label": 0}
# {"img_local_path": "test/65.jpg", "original_caption1": "Policemen stand guard near the state secretariat anticipating protests following reports of two women of menstruating age entering the Sabarimala temple, one of the world's largest Hindu pilgrimage sites, in Thiruvananthapuram, Kerala, India, last week.", "caption1_mod": "Policemen stand guard near the state secretariat anticipating protests following reports of CARDINAL women of  age entering the GPE temple, one of the world's largest NORP pilgrimage sites, in GPE, GPE, GPE, DATE.", "img_gen1": "DallE-GeneratedDataset/images/65_gen1.png", "original_caption2": "Defying Court Order, Police Bar 10 Women from Praying at Ancient Temple in Indian State: Reports", "caption2_mod": "Defying Court Order, Police Bar 10 Women from Praying at Ancient Temple in NORP State: Reports", "img_gen2": "DallE-GeneratedDataset/images/65_gen2.png", "label": 0}
# {"img_local_path": "test/66.jpg", "original_caption1": "Jemal Ahmed chases away a swarm of locusts, after the locusts stormed his sorghum and sweet cane farm in Jawaha, Ethiopia.", "caption1_mod": "PERSON chases away a swarm of locusts, after the locusts stormed his sorghum and sweet cane farm in GPE, GPE.", "img_gen1": "DallE-GeneratedDataset/images/66_gen1.png", "original_caption2": "A man chases away locusts from his crops", "caption2_mod": "A man chases away locusts from his crops", "img_gen2": "DallE-GeneratedDataset/images/66_gen2.png", "label": 0}
# {"img_local_path": "test/67.jpg", "original_caption1": "A member of a feminist collective paints the helmet of a riot police officer during a protest against gender and police violence, in Mexico City, Mexico November 11, 2020.", "caption1_mod": "A member of a feminist collective paints the helmet of a riot police officer during a protest against gender and police violence, in GPE, GPE DATE.", "img_gen1": "DallE-GeneratedDataset/images/67_gen1.png", "original_caption2": "A demonstrator paints the helmet visor of a riot police officer, in Mexico City, Mexico, 11 November 2021", "caption2_mod": "A demonstrator paints the helmet visor of a riot police officer, in GPE, GPE, DATE", "img_gen2": "DallE-GeneratedDataset/images/67_gen2.png", "label": 0}
# {"img_local_path": "test/68.jpg", "original_caption1": "President Obama passed a law requiring Grandparents to Get All Their Grandchildren Every Weekend.", "caption1_mod": "President PERSON passed a law requiring Grandparents to Get All Their Grandchildren Every Weekend.", "img_gen1": "DallE-GeneratedDataset/images/68_gen1.png", "original_caption2": "Reports that President Obama had passed a law requiring grandparents to pick up their grandchildren every weekend came from a site that generates user-created hoax news.", "caption2_mod": "Reports that President PERSON had passed a law requiring grandparents to pick up their grandchildren DATE came from a site that generates user-created hoax news.", "img_gen2": "DallE-GeneratedDataset/images/68_gen2.png", "label": 1}
# {"img_local_path": "test/69.jpg", "original_caption1": "a woman walks past a mural reminding Abidjan's residents of anti-coronavirus hygiene measures", "caption1_mod": "a woman walks past a mural reminding ORG's residents of anti- hygiene measures", "img_gen1": "DallE-GeneratedDataset/images/69_gen1.png", "original_caption2": "a large mural depicting a person wearing a mask", "caption2_mod": "a large mural depicting a person wearing a mask", "img_gen2": "DallE-GeneratedDataset/images/69_gen2.png", "label": 0}
# ...
# {"img_local_path": "test/1675.jpg", "original_caption1": "Almaty, Kazakhstan: a tamed golden eagle takes part in a traditional hunting contest", "caption1_mod": "Almaty, PERSON: a tamed golden eagle takes part in a traditional hunting contest", "img_gen1": "DallE-GeneratedDataset/images/1675_gen1.png", "original_caption2": "A number of citizens of Kazakhstan are participating in a traditional hunting contest with their pet golden eagles in an area near the town of Esik in Almaty.", "caption2_mod": "A number of citizens of GPE are participating in a traditional hunting contest with their pet golden eagles in an area near the town of Esik in Almaty.", "img_gen2": "DallE-GeneratedDataset/images/1675_gen2.png", "label": 0}
# {"img_local_path": "test/1676.jpg", "original_caption1": "How Julia Jordan, Champion of Female Playwrights, Spends Her Sundays", "caption1_mod": "How Julia PERSON, Champion of Female Playwrights, Spends Her Sundays", "img_gen1": "DallE-GeneratedDataset/images/1676_gen1.png", "original_caption2": "\u201cI\u2019m primarily the dog walker, but usually the kids come with me.\u201d", "caption2_mod": "\u201cI\u2019m primarily the dog walker, but usually the kids come with me.\u201d", "img_gen2": "DallE-GeneratedDataset/images/1676_gen2.png", "label": 0}
# {"img_local_path": "test/1677.jpg", "original_caption1": "Kendrick Lamar bought and publicly destroyed the gun used by George Zimmerman to kill Trayvon Martin.", "caption1_mod": "PERSON bought and publicly destroyed the gun used by PERSON to  PERSON.", "img_gen1": "DallE-GeneratedDataset/images/1677_gen1.png", "original_caption2": "Lamar preforming in 2013.", "caption2_mod": "GPE preforming in DATE.", "img_gen2": "DallE-GeneratedDataset/images/1677_gen2.png", "label": 1}
# {"img_local_path": "test/1678.jpg", "original_caption1": "A photographer's self portrait with her mother is one of many works featured at the Bronx Documentary Center's third Annual Latin American Foto Festival.", "caption1_mod": "A photographer's self portrait with her mother is one of many works featured at FAC ORDINAL Annual NORP EVENT.", "img_gen1": "DallE-GeneratedDataset/images/1678_gen1.png", "original_caption2": "Two women embrace, wearing face masks", "caption2_mod": "CARDINAL women embrace, wearing face masks", "img_gen2": "DallE-GeneratedDataset/images/1678_gen2.png", "label": 0}
# {"img_local_path": "test/1679.jpg", "original_caption1": "Buildings around the UK were also lit in blue - the colour of the NHS logo - to pay tribute to the work of NHS staff.", "caption1_mod": "Buildings around the GPE were also lit in blue - the colour of the ORG logo - to pay tribute to the work of ORG staff.", "img_gen1": "DallE-GeneratedDataset/images/1679_gen1.png", "original_caption2": "Falkirk is home to The Kelpies, the largest equine sculptures in the world", "caption2_mod": "ORG is home to ORG, the largest equine sculptures in the world", "img_gen2": "DallE-GeneratedDataset/images/1679_gen2.png", "label": 0}
# {"img_local_path": "test/1680.jpg", "original_caption1": "The stamps seen in news pictures of the packages were uncancelled, demonstrating that the parcels had not in fact gone through the mail system", "caption1_mod": "The stamps seen in news pictures of the packages were uncancelled, demonstrating that the parcels had not in fact gone through the mail system", "img_gen1": "DallE-GeneratedDataset/images/1680_gen1.png", "original_caption2": "A handout photo made available by the Federal Bureau of Investigation (FBI) on shows the exterior of one of the suspicious packages which were received at multiple locations in the New York and Washington, D.C., areas and Florida between October 22 and 24, 2018.", "caption2_mod": "A handout photo made available by ORG (ORG) on shows the exterior of CARDINAL of the suspicious packages which were received at multiple locations in the GPE and GPE, GPE, areas and GPE DATE.", "img_gen2": "DallE-GeneratedDataset/images/1680_gen2.png", "label": 1}
# {"img_local_path": "test/1681.jpg", "original_caption1": "President Lyndon Johnson holds one of his beagles, named Him, as he speaks with members of the White House press corps in 1964.", "caption1_mod": "President PERSON holds CARDINAL of his beagles, named Him, as he speaks with members of the ORG press corps in DATE.", "img_gen1": "DallE-GeneratedDataset/images/1681_gen1.png", "original_caption2": "President Lyndon Johnson holds a beagle dog whilst speaking to a group of journalists", "caption2_mod": "President PERSON holds a beagle dog whilst speaking to a group of journalists", "img_gen2": "DallE-GeneratedDataset/images/1681_gen2.png", "label": 0}
# {"img_local_path": "test/1682.jpg", "original_caption1": "George Soros. A SS in the National Socialist German workers party. Nazi party. He served under Hitler.", "caption1_mod": "PERSON. A ORG in ORG workers party. NORP party. He served under PERSON.", "img_gen1": "DallE-GeneratedDataset/images/1682_gen1.png", "original_caption2": "Soros couldn\u2019t have joined the SS whose minimum age requirement was 17 even if he had wanted to.", "caption2_mod": "PERSON couldn\u2019t have joined the ORG whose minimum age requirement was CARDINAL even if he had wanted to.", "img_gen2": "DallE-GeneratedDataset/images/1682_gen2.png", "label": 1}
# {"img_local_path": "test/1683.png", "original_caption1": "Posts shared on social media about the event purported to document the display of Nazi and Confederate flags offered for sale at the rally", "caption1_mod": "Posts shared on social media about the event purported to document the display of NORP and ORG flags offered for sale at the rally", "img_gen1": "DallE-GeneratedDataset/images/1683_gen1.png", "original_caption2": "The image had been snapped at the Braddock\u2019s Inn flea market in Pennsylvania over two months earlier, and the vendor displaying the offending material removed it upon request", "caption2_mod": "The image had been snapped at the PERSON\u2019s Inn flea market in GPE over DATE, and the vendor displaying the offending material removed it upon request", "img_gen2": "DallE-GeneratedDataset/images/1683_gen2.png", "label": 1}
# {"img_local_path": "test/1684.jpg", "original_caption1": "United States would be designating \u201cANTIFA\u201d as a \u201cTerrorist Organization.\u201d", "caption1_mod": "GPE would be designating \u201cORG\u201d as ORG.\u201d", "img_gen1": "DallE-GeneratedDataset/images/1684_gen1.png", "original_caption2": "A protester with an ANTIFA flag draped over his shoulders during a rally in Boston on May 31, 2020.", "caption2_mod": "A protester with an NORP flag dd over his shoulders during a rally in GPE on DATE.", "img_gen2": "DallE-GeneratedDataset/images/1684_gen2.png", "label": 1}
# {"img_local_path": "test/1685.JPG", "original_caption1": "People walk near the showrooms of Chinese and foreign car dealerships in Beijing. China\u2019s auto industry has been hit hard by the coronavirus.", "caption1_mod": "People walk near the showrooms of NORP and foreign car dealerships in GPE. GPE\u2019s auto industry has been hit hard by the .", "img_gen1": "DallE-GeneratedDataset/images/1685JPG_gen1.png", "original_caption2": "FILE PHOTO: People walk near the showrooms of Chinese and foreign car dealerships in Beijing, China, Oct. 11, 2018.", "caption2_mod": "FILE PHOTO: People walk near the showrooms of NORP and foreign car dealerships in GPE, GPE, DATE.", "img_gen2": "DallE-GeneratedDataset/images/1685JPG_gen2.png", "label": 0}
# {"img_local_path": "test/1686.png", "original_caption1": "A photo shows Queen Elizabeth laughing after Prince Philip \"pranked\" her by disguising himself as a palace guard.", "caption1_mod": "A photo shows PERSON laughing after PERSONpranked\" her by disguising himself as a palace guard.", "img_gen1": "DallE-GeneratedDataset/images/1686_gen1.png", "original_caption2": "The prince and queen shortly before a ceremonial review of the Grenadier Guards at Windsor Castle.", "caption2_mod": "The prince and queen shortly before a ceremonial review of the Grenadier Guards at FAC.", "img_gen2": "DallE-GeneratedDataset/images/1686_gen2.png", "label": 1}
# {"img_local_path": "test/1687.jpg", "original_caption1": "Oggi Tomic taking a photo", "caption1_mod": "Oggi Tomic taking a photo", "img_gen1": "DallE-GeneratedDataset/images/1687_gen1.png", "original_caption2": "A child holds a camera next to a destroyed bus", "caption2_mod": "A child holds a camera next to a destroyed bus", "img_gen2": "DallE-GeneratedDataset/images/1687_gen2.png", "label": 0}
# {"img_local_path": "test/1688.jpg", "original_caption1": "Zuckerberg secretly bought the \u201csuper yacht,\u201d Ulysses, from a reclusive New Zealand businessman, Graeme Hart, for $150 million in October 2017.", "caption1_mod": "PERSON secretly bought the \u201csuper yacht,\u201d Ulysses, from a reclusive GPE businessman, PERSON, for MONEY in DATE.", "img_gen1": "DallE-GeneratedDataset/images/1688_gen1.png", "original_caption2": "The reports related to Mark purchasing a yacht are completely inaccurate as he did not purchase a yacht.", "caption2_mod": "The reports related to PERSON purchasing a yacht are completely inaccurate as he did not purchase a yacht.", "img_gen2": "DallE-GeneratedDataset/images/1688_gen2.png", "label": 1}
# {"img_local_path": "test/1689.jpg", "original_caption1": "Supporters of Felix Tshisekedi, the newly declared winner, in Kinshasa on Thursday.", "caption1_mod": "Supporters of Felix Tshisekedi, the newly declared winner, in ORG on DATE.", "img_gen1": "DallE-GeneratedDataset/images/1689_gen1.png", "original_caption2": "Residents celebrate in Kinshasa, Congo, on Thursday after the election results were announced.", "caption2_mod": "Residents celebrate in GPE, GPE, on DATE after the election results were announced.", "img_gen2": "DallE-GeneratedDataset/images/1689_gen2.png", "label": 0}
# {"img_local_path": "test/1690.jpg", "original_caption1": "A video clip shows supporters of U.S. Sen. Bernie Sanders failing to identify a single country on an unlabeled world map.", "caption1_mod": "A video clip shows supporters of GPE Sen. PERSON failing to identify a single country on an unlabeled world map.", "img_gen1": "DallE-GeneratedDataset/images/1690_gen1.png", "original_caption2": "The video tweeted by Cruz was taken from a comedy segment taped for the \u201cJimmy Kimmel Live\u201d late night talk show back in 2018, before Sanders entered the race for the 2020 Democratic presidential nomination.", "caption2_mod": "The video tweeted by PERSON was taken from a comedy segment taped for the \u201c Live\u201d TIME talk show back in DATE, before ORG entered the race for the DATE NORP presidential nomination.", "img_gen2": "DallE-GeneratedDataset/images/1690_gen2.png", "label": 1}
# {"img_local_path": "test/1691.jpg", "original_caption1": "A man exercises on a street in Edinburgh", "caption1_mod": "A man exercises on a street in GPE", "img_gen1": "DallE-GeneratedDataset/images/1691_gen1.png", "original_caption2": "A man jumps over a skipping rope in a street", "caption2_mod": "A man jumps over a skipping rope in a street", "img_gen2": "DallE-GeneratedDataset/images/1691_gen2.png", "label": 0}
# {"img_local_path": "test/1692.jpg", "original_caption1": "A video shows a naked child using bedsheets to escape from an upper story of Buckingham Palace.", "caption1_mod": "A video shows a  child using bedsheets to escape from an upper story of FAC.", "img_gen1": "DallE-GeneratedDataset/images/1692_gen1.png", "original_caption2": "The naked man was actually escaping from Princess Eleanor\u2019s (Alexandra Park) chambers", "caption2_mod": "The  man was actually escaping from Princess PERSON\u2019s (GPE) chambers", "img_gen2": "DallE-GeneratedDataset/images/1692_gen2.png", "label": 1}
# {"img_local_path": "test/1693.jpg", "original_caption1": "Nabhaan Rizwan, left, and Roger Jean Nsengiyumva in \"Informer.\"", "caption1_mod": "PERSON, left, and PERSON in \"WORK_OF_ART.\"", "img_gen1": "DallE-GeneratedDataset/images/1693_gen1.png", "original_caption2": "Nabhaan Rizwan and Roger Jean Nsengiyumva", "caption2_mod": "PERSON and PERSON", "img_gen2": "DallE-GeneratedDataset/images/1693_gen2.png", "label": 0}
# {"img_local_path": "test/1694.jpg", "original_caption1": "The inaugural committee spent $924,000 on seven-foot-high wreaths, moss-covered obelisks, flowers and other decorations to dress up Union Station.", "caption1_mod": "The inaugural committee spent $MONEY on QUANTITY-high wreaths, moss-covered obelisks, flowers and other decorations to dress up ORG.", "img_gen1": "DallE-GeneratedDataset/images/1694_gen1.png", "original_caption2": "The inaugural committee spent $924,000 on seven-foot-high wreaths, moss-covered obelisks, flowers and other decorations to dress up Union Station.", "caption2_mod": "The inaugural committee spent $MONEY on QUANTITY-high wreaths, moss-covered obelisks, flowers and other decorations to dress up ORG.", "img_gen2": "DallE-GeneratedDataset/images/1694_gen2.png", "label": 0}
# {"img_local_path": "test/1695.jpg", "original_caption1": "President Obama trademarked the name 'Obamacare' and receives royalties every time the term is used.", "caption1_mod": "President PERSON trademarked the name 'ORG' and receives royalties every time the term is used.", "img_gen1": "DallE-GeneratedDataset/images/1695_gen1.png", "original_caption2": "There was no truth that Obama family millions of dollars with Obamacare", "caption2_mod": "There was no truth that PERSON family MONEY with care", "img_gen2": "DallE-GeneratedDataset/images/1695_gen2.png", "label": 1}
# {"img_local_path": "test/1696.jpg", "original_caption1": "A photograph shows a soldier carrying a donkey on his back during World War II to prevent the animal from inadvertently setting off landmines.", "caption1_mod": "A photograph shows a soldier carrying a donkey on his back during EVENT to prevent the animal from inadvertently setting off landmines.", "img_gen1": "DallE-GeneratedDataset/images/1696_gen1.png", "original_caption2": "Coronavirus meme featuring \u201cWWII donkey\u201d is not what it claims to be", "caption2_mod": "ORG meme featuring \u201cEVENT donkey\u201d is not what it claims to be", "img_gen2": "DallE-GeneratedDataset/images/1696_gen2.png", "label": 1}
# {"img_local_path": "test/1697.jpg", "original_caption1": "Homeless people living on streets in Denver", "caption1_mod": "Homeless people living on streets in GPE", "img_gen1": "DallE-GeneratedDataset/images/1697_gen1.png", "original_caption2": "The State Capitol Building in Colorado", "caption2_mod": "The State Capitol Building in GPE", "img_gen2": "DallE-GeneratedDataset/images/1697_gen2.png", "label": 0}
# {"img_local_path": "test/1698.jpg", "original_caption1": "The castle's esplanade was a perfect spot for some off-piste skiing", "caption1_mod": "The castle's esplanade was a perfect spot for some off-piste skiing", "img_gen1": "DallE-GeneratedDataset/images/1698_gen1.png", "original_caption2": "Picture shows an Edinburgh skier", "caption2_mod": "Picture shows an PERSON skier", "img_gen2": "DallE-GeneratedDataset/images/1698_gen2.png", "label": 0}
# {"img_local_path": "test/1699.jpg", "original_caption1": "We are confident that our reporting will stand up, said Ben Smith, the editor in chief of BuzzFeed News.", "caption1_mod": "We are confident that our reporting will stand up, said PERSON, the editor in chief of ORG.", "img_gen1": "DallE-GeneratedDataset/images/1699_gen1.png", "original_caption2": "BuzzFeed News Editor-in-Chief Ben Smith poses for a picture in his office in the newsroom at BuzzFeed headquarters.", "caption2_mod": "ORG-in-Chief PERSON poses for a picture in his office in the newsroom at FAC headquarters.", "img_gen2": "DallE-GeneratedDataset/images/1699_gen2.png", "label": 1}

# %%
from IPython.display import display
import cv2
from google.colab.patches import cv2_imshow
import json
with open("DALLE.json") as f:
  test_data = [json.loads(line) for line in f]
  for i in test_data[:5]:
    print(i['img_local_path'])
    print("OG C1",i['original_caption1'])
    print("OG C2",i['original_caption2'])
    img = i['img_gen1']
    print(img)
    n = cv2.imread(img)
    cv2_imshow(n)
    print("Mod C1",i['caption1_mod'])
    img2 = i['img_gen2']
    print(img2)
    n2 = cv2.imread(img2)
    cv2_imshow(n2)
    print("Mod C2",i['caption2_mod'])
    print("Context Label",i['label'])
